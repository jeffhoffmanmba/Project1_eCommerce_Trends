# %% [raw]
# #########################################################################################################
# #  RUT-SOM-DATA-PT-06-2020-U-C                                                             Douglas High #
# #     Project1                                                                            July 27, 2020 #
# #    program-name = censusdata_extraction                                                               #
# #00    > read in US Census bureau data file and key files for Monthly Trade and                         #
# #        Retail Food Sales (MRTS), merge files on key values.                                           #
# #01    > keep only non adjusted sales (is_adj=0), monthly sales(SM) and Monthly Percentage              #
# #        Change(MPSCM) for electronic shopping and mail order(4541) and MRTFS excluding                 #
# #        automotive and fuel sales (44W72) between 2010 and 2020 (inclusive).                           #
# #      > create complete df and write to csv.                                                           #
# #02    > create two output csv files, summarizing monthly sales and annual sales for both ecomm         #
# #        and instore purchases.                                                                         #
# #########################################################################################################

# %%
####################################################
#00     I/O and Table S/U                          #
#   a- import code.                                #
#   b- associate files to variables.               #  
#   c- read input files into df's.                 #
#   d- merge df's (except error & geo (currently   #
#      only error code 0 and gecode 1 (US))).      #
####################################################

#a
import pandas as pd
import numpy as np
import requests
import json
import warnings; warnings.simplefilter('ignore')

#b
codes_dtypes ="datain/MRTS_Dtypes.csv"
codes_months ="datain/MRTS_months.csv"
codes_cats ="datain/MRTS_cats.csv"
codes_geo ="datain/MRTS_geo.csv"
codes_err ="datain/MRTS_errors.csv"
data_in = "datain/MRTS_data.csv"      

#c
geo_df = pd.read_csv(codes_geo)     #currently only code=1(US), not merging
err_df = pd.read_csv(codes_err)     #currently no error codes, not merging 
data_df = pd.read_csv(data_in)      #val="(S)" records manually removed, all non MRTFS records
cats_df = pd.read_csv(codes_cats)
months_df = pd.read_csv(codes_months)
dtypes_df = pd.read_csv(codes_dtypes)   

#d
cats_merge = pd.merge(data_df,cats_df, how="inner", on=["cat_idx"])
mnth_merge = pd.merge(cats_merge,months_df, how="left", on=["per_idx"])
dtyp_merge = pd.merge(mnth_merge,dtypes_df, how="left", on=["dt_idx"])

# %%
###########################################################################################
#01      Create Complete Dataframe                                                        #
#   a- keep only sales and perchange for non-adjusted retail.                             #
#   b- split month and year, if year not numeric, switch with month, capitalize month.    #
#    (format of per_name changes Jan/2001 (Mmm-yy --> yy-mmm))                            #
#   c- keep only records from 2010-2020.                                                  # 
#   e- complete_df: reorder columns, dropping index columns, sort, and write to csv.      #
###########################################################################################

#a
dtyp_merge =dtyp_merge[((dtyp_merge["cat_code"] == "44W72") | (dtyp_merge["cat_code"] == "4541")) &
                       ((dtyp_merge["dt_code"] == "SM") | (dtyp_merge["dt_code"] == "MPCSM")) & (dtyp_merge["is_adj"] == 0)]

#b
dtyp_merge["month"], dtyp_merge["year"] = dtyp_merge['per_name'].str.split('-', 1).str
dtyp_merge["year"] = pd.to_numeric(dtyp_merge["year"])
dtyp_merge["mon/yy"] = ""
dtyp_merge["val"].astype(float)                       # convert value field for aggregation

for x, row in dtyp_merge.iterrows():
    if dtyp_merge["month"][x].isnumeric():            # switch month and year if new format
        month_hold = dtyp_merge["year"][x]
        dtyp_merge["year"][x] = dtyp_merge["month"][x]
        dtyp_merge["month"][x] = month_hold
        dtyp_merge["month"][x] = dtyp_merge["month"][x].title()     #title all months to match old naming convention
    dtyp_merge["mon/yy"][x] = dtyp_merge["month"][x] + "/" + dtyp_merge["year"][x].astype(str)

#c
dtyp_merge = dtyp_merge[(dtyp_merge["year"] >= 10) & (dtyp_merge["year"] <= 20)]
dtyp_merge.reset_index(inplace=True,drop=True)
dtyp_merge["year"] = dtyp_merge["year"] + 2000
    
#d
complete_df = pd.DataFrame({"month": dtyp_merge["month"], "year": dtyp_merge["year"], "amount": dtyp_merge["val"],
                  "dt_unit": dtyp_merge["dt_unit"], "dt_code": dtyp_merge["dt_code"], "dt_desc": dtyp_merge["dt_desc"],
                  "cat_code": dtyp_merge["cat_code"], "cat_desc": dtyp_merge["cat_desc"],"monthyear" : dtyp_merge["mon/yy"]})

complete_df.sort_values(["cat_code", "dt_code"], inplace=True,ascending=False)
complete_df.reset_index(inplace=True, drop=True)
complete_df.to_csv("Data/censusdata_complete.csv", index=False, header=True)

# %%
###############################################################
#02      Monthly and Annual Summary                           #
#   a- split df into e-comm and in store for monthly sales.   #
#   b- create monthly df of sales information.                #
#   c- aggregate data and create annual summary df.           #  
#   d- write out df's to csv files.                           # 
###############################################################

#a
ecomm_sales = complete_df[(complete_df["cat_code"] == "4541") & (complete_df["dt_code"] == "SM")]
ecomm_sales.reset_index(inplace=True,drop=True)

comm_sales = complete_df[(complete_df["cat_code"] == "44W72")& (complete_df["dt_code"] == "SM")]
comm_sales.reset_index(inplace=True,drop=True)

#b
monthly_sales_both = pd.DataFrame({"month": ecomm_sales["month"], "year": ecomm_sales["year"], 
                       "ecomm sales(MIL$)": ecomm_sales["amount"].astype(int), "instore sales(MIL$)": comm_sales["amount"].astype(int),
                       "ecomm %":  round(ecomm_sales["amount"] / (ecomm_sales["amount"] + comm_sales["amount"]) * 100,2),
                       "total sales": (ecomm_sales["amount"] + comm_sales["amount"]).astype(int)})
#c
ecomm_annual_sales = (ecomm_sales.groupby("year")["amount"].sum()).astype(int)
comm_annual_sales = (comm_sales.groupby("year")["amount"].sum()).astype(int)
total_annual_sales = ecomm_annual_sales + comm_annual_sales
ecom_per = round((ecomm_annual_sales / total_annual_sales) * 100,2)
years = ecomm_sales.groupby('year')["year"].mean()


yearly_sales_both = pd.DataFrame({"year": years, "ecomm sales(MIL$)": ecomm_annual_sales, "instore sales(MIL$)": comm_annual_sales,
                                  "ecomm %": ecom_per, "total sales": total_annual_sales})
#d
monthly_sales_both.to_csv("Data/censusdata_monthly_sales_both.csv", index=False, header=True)
yearly_sales_both.to_csv("Data/censusdata_yearly_sales_both.csv", index=False, header=True)

# %%
covidurl = "https://covidtracking.com/api/v1/states/daily.json"
import requests
import json

# %%
response = requests.get("https://covidtracking.com/api/v1/states/daily.json")

# %%
response.json()
# Out:
# [{'date': 20200725,
#   'state': 'AK',
#   'positive': 2868,
#   'negative': 202198,
#   'pending': None,
#   'hospitalizedCurrently': 38,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 2,
#   'onVentilatorCumulative': None,
#   'recovered': 815,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 20,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 205066,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 2868,
#   'deathConfirmed': 20,
#   'deathProbable': None,
#   'fips': '02',
#   'positiveIncrease': 120,
#   'negativeIncrease': 4374,
#   'total': 205066,
#   'totalTestResults': 205066,
#   'totalTestResultsIncrease': 4494,
#   'posNeg': 205066,
#   'deathIncrease': 1,
#   'hospitalizedIncrease': 0,
#   'hash': '5f2c5ca08d30c7fa77bfd21e75840efa1435f3cd',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'AL',
#   'positive': 78130,
#   'negative': 563481,
#   'pending': None,
#   'hospitalizedCurrently': 1425,
#   'hospitalizedCumulative': 9157,
#   'inIcuCurrently': None,
#   'inIcuCumulative': 1069,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': 567,
#   'recovered': 32510,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 11:00',
#   'dateModified': '2020-07-25T11:00:00Z',
#   'checkTimeEt': '07/25 07:00',
#   'death': 1456,
#   'hospitalized': 9157,
#   'dateChecked': '2020-07-25T11:00:00Z',
#   'totalTestsViral': 639795,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 76314,
#   'deathConfirmed': 1413,
#   'deathProbable': 43,
#   'fips': '01',
#   'positiveIncrease': 2125,
#   'negativeIncrease': 10502,
#   'total': 641611,
#   'totalTestResults': 641611,
#   'totalTestResultsIncrease': 12627,
#   'posNeg': 641611,
#   'deathIncrease': 18,
#   'hospitalizedIncrease': 0,
#   'hash': '8d1bda5ff4d4985142b55becccbea692e56abfda',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'AR',
#   'positive': 37249,
#   'negative': 424215,
#   'pending': None,
#   'hospitalizedCurrently': 497,
#   'hospitalizedCumulative': 2361,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 109,
#   'onVentilatorCumulative': 329,
#   'recovered': 29827,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 394,
#   'hospitalized': 2361,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 461464,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 37249,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '05',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 461464,
#   'totalTestResults': 461464,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 461464,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'a3452a99a044e2e12f08a21b96dbef0d9362e5c2',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'AS',
#   'positive': 0,
#   'negative': 1037,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'C',
#   'lastUpdateEt': '7/16/2020 00:00',
#   'dateModified': '2020-07-16T00:00:00Z',
#   'checkTimeEt': '07/15 20:00',
#   'death': 0,
#   'hospitalized': None,
#   'dateChecked': '2020-07-16T00:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 0,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '60',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 1037,
#   'totalTestResults': 1037,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 1037,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '0d7a633be32b1ba4de5e5b83e4541495d606dc79',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'AZ',
#   'positive': 160041,
#   'negative': 697568,
#   'pending': None,
#   'hospitalizedCurrently': 2758,
#   'hospitalizedCumulative': 7627,
#   'inIcuCurrently': 842,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 594,
#   'onVentilatorCumulative': None,
#   'recovered': 20566,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 3286,
#   'hospitalized': 7627,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 857609,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 137710,
#   'deathConfirmed': 2431,
#   'deathProbable': 152,
#   'fips': '04',
#   'positiveIncrease': 3740,
#   'negativeIncrease': 17052,
#   'total': 857609,
#   'totalTestResults': 857609,
#   'totalTestResultsIncrease': 20792,
#   'posNeg': 857609,
#   'deathIncrease': 144,
#   'hospitalizedIncrease': 166,
#   'hash': '086654feacad18d4c1af2297f08891f51d9cbcc2',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'CA',
#   'positive': 445400,
#   'negative': 6601955,
#   'pending': None,
#   'hospitalizedCurrently': 8820,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 2284,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 8337,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 7047355,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 445400,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '06',
#   'positiveIncrease': 10066,
#   'negativeIncrease': 121413,
#   'total': 7047355,
#   'totalTestResults': 7047355,
#   'totalTestResultsIncrease': 131479,
#   'posNeg': 7047355,
#   'deathIncrease': 151,
#   'hospitalizedIncrease': 0,
#   'hash': '1c3c5e5d7d8a78e1027e606bc3fe62b193ea414e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'CO',
#   'positive': 42980,
#   'negative': 436764,
#   'pending': None,
#   'hospitalizedCurrently': 357,
#   'hospitalizedCumulative': 6227,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 5133,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/25/2020 01:59',
#   'dateModified': '2020-07-25T01:59:00Z',
#   'checkTimeEt': '07/24 21:59',
#   'death': 1661,
#   'hospitalized': 6227,
#   'dateChecked': '2020-07-25T01:59:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 39822,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '08',
#   'positiveIncrease': 666,
#   'negativeIncrease': 8201,
#   'total': 479744,
#   'totalTestResults': 479744,
#   'totalTestResultsIncrease': 8867,
#   'posNeg': 479744,
#   'deathIncrease': 16,
#   'hospitalizedIncrease': 78,
#   'hash': 'bc198d3a640eaf873bfd84af534ba87633fa5667',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'CT',
#   'positive': 48776,
#   'negative': 664296,
#   'pending': None,
#   'hospitalizedCurrently': 71,
#   'hospitalizedCumulative': 10712,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 8516,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/23/2020 20:30',
#   'dateModified': '2020-07-23T20:30:00Z',
#   'checkTimeEt': '07/23 16:30',
#   'death': 4413,
#   'hospitalized': 10712,
#   'dateChecked': '2020-07-23T20:30:00Z',
#   'totalTestsViral': 711102,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 46806,
#   'deathConfirmed': 3531,
#   'deathProbable': 882,
#   'fips': '09',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 713072,
#   'totalTestResults': 713072,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 713072,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '20e8714f734e11c6fb8cade35dc760f724f615e4',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'DC',
#   'positive': 11717,
#   'negative': 157292,
#   'pending': None,
#   'hospitalizedCurrently': 97,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 28,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 9,
#   'onVentilatorCumulative': None,
#   'recovered': 9603,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 00:00',
#   'dateModified': '2020-07-24T00:00:00Z',
#   'checkTimeEt': '07/23 20:00',
#   'death': 581,
#   'hospitalized': None,
#   'dateChecked': '2020-07-24T00:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '11',
#   'positiveIncrease': 68,
#   'negativeIncrease': 3681,
#   'total': 169009,
#   'totalTestResults': 169009,
#   'totalTestResultsIncrease': 3749,
#   'posNeg': 169009,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '5c8a480b86a8677dffec221247baa4d18637377e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'DE',
#   'positive': 14175,
#   'negative': 152747,
#   'pending': None,
#   'hospitalizedCurrently': 55,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 11,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 7961,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 18:00',
#   'dateModified': '2020-07-24T18:00:00Z',
#   'checkTimeEt': '07/24 14:00',
#   'death': 579,
#   'hospitalized': None,
#   'dateChecked': '2020-07-24T18:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 13179,
#   'deathConfirmed': 509,
#   'deathProbable': 70,
#   'fips': '10',
#   'positiveIncrease': -27,
#   'negativeIncrease': 2623,
#   'total': 166922,
#   'totalTestResults': 166922,
#   'totalTestResultsIncrease': 2596,
#   'posNeg': 166922,
#   'deathIncrease': 1,
#   'hospitalizedIncrease': 0,
#   'hash': 'acad789ed071290e1c75c4b9fa51a7c3575d8cc1',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'FL',
#   'positive': 414511,
#   'negative': 2921866,
#   'pending': 2850,
#   'hospitalizedCurrently': 9035,
#   'hospitalizedCumulative': 24086,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/24/2020 23:59',
#   'dateModified': '2020-07-24T23:59:00Z',
#   'checkTimeEt': '07/24 19:59',
#   'death': 5894,
#   'hospitalized': 24086,
#   'dateChecked': '2020-07-24T23:59:00Z',
#   'totalTestsViral': 4263177,
#   'positiveTestsViral': 519405,
#   'negativeTestsViral': 3728507,
#   'positiveCasesViral': 414511,
#   'deathConfirmed': 5894,
#   'deathProbable': None,
#   'fips': '12',
#   'positiveIncrease': 12199,
#   'negativeIncrease': 47542,
#   'total': 3339227,
#   'totalTestResults': 3336377,
#   'totalTestResultsIncrease': 59741,
#   'posNeg': 3336377,
#   'deathIncrease': 126,
#   'hospitalizedIncrease': 511,
#   'hash': '3f08ebfa8aca0075ff0c4544a09b897583be0926',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'GA',
#   'positive': 165188,
#   'negative': 1242652,
#   'pending': None,
#   'hospitalizedCurrently': 3094,
#   'hospitalizedCumulative': 17029,
#   'inIcuCurrently': None,
#   'inIcuCumulative': 3158,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/25/2020 14:50',
#   'dateModified': '2020-07-25T14:50:00Z',
#   'checkTimeEt': '07/25 10:50',
#   'death': 3495,
#   'hospitalized': 17029,
#   'dateChecked': '2020-07-25T14:50:00Z',
#   'totalTestsViral': 1407840,
#   'positiveTestsViral': 150626,
#   'negativeTestsViral': 1257214,
#   'positiveCasesViral': 165188,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '13',
#   'positiveIncrease': 3787,
#   'negativeIncrease': 21609,
#   'total': 1407840,
#   'totalTestResults': 1407840,
#   'totalTestResultsIncrease': 25396,
#   'posNeg': 1407840,
#   'deathIncrease': 53,
#   'hospitalizedIncrease': 277,
#   'hash': '72194b31f2c3722d6981348e92bbd755f80030be',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'GU',
#   'positive': 337,
#   'negative': 19695,
#   'pending': None,
#   'hospitalizedCurrently': 1,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 244,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/24/2020 20:40',
#   'dateModified': '2020-07-24T20:40:00Z',
#   'checkTimeEt': '07/24 16:40',
#   'death': 5,
#   'hospitalized': None,
#   'dateChecked': '2020-07-24T20:40:00Z',
#   'totalTestsViral': 19791,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 329,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '66',
#   'positiveIncrease': 0,
#   'negativeIncrease': 563,
#   'total': 20032,
#   'totalTestResults': 20032,
#   'totalTestResultsIncrease': 563,
#   'posNeg': 20032,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'c1a17ec1fc4b397c596611eff1e84b512be4b9c3',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'HI',
#   'positive': 1549,
#   'negative': 111241,
#   'pending': None,
#   'hospitalizedCurrently': 29,
#   'hospitalizedCumulative': 156,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 1148,
#   'dataQualityGrade': 'D',
#   'lastUpdateEt': '7/24/2020 18:00',
#   'dateModified': '2020-07-24T18:00:00Z',
#   'checkTimeEt': '07/24 14:00',
#   'death': 26,
#   'hospitalized': 156,
#   'dateChecked': '2020-07-24T18:00:00Z',
#   'totalTestsViral': 138354,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '15',
#   'positiveIncrease': 59,
#   'negativeIncrease': 1440,
#   'total': 112790,
#   'totalTestResults': 112790,
#   'totalTestResultsIncrease': 1499,
#   'posNeg': 112790,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 1,
#   'hash': '6275ff71d6884b605f00db0bb78a4619ac1f9e37',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'IA',
#   'positive': 41671,
#   'negative': 404592,
#   'pending': None,
#   'hospitalizedCurrently': 220,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 72,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 28,
#   'onVentilatorCumulative': None,
#   'recovered': 29477,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 826,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 41671,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '19',
#   'positiveIncrease': 400,
#   'negativeIncrease': 3990,
#   'total': 446263,
#   'totalTestResults': 446263,
#   'totalTestResultsIncrease': 4390,
#   'posNeg': 446263,
#   'deathIncrease': 3,
#   'hospitalizedIncrease': 0,
#   'hash': '092fd583182cf08a2c51697a252b7acd42f70b62',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'ID',
#   'positive': 17264,
#   'negative': 146176,
#   'pending': None,
#   'hospitalizedCurrently': 204,
#   'hospitalizedCumulative': 709,
#   'inIcuCurrently': 45,
#   'inIcuCumulative': 210,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 5251,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/24/2020 19:00',
#   'dateModified': '2020-07-24T19:00:00Z',
#   'checkTimeEt': '07/24 15:00',
#   'death': 144,
#   'hospitalized': 709,
#   'dateChecked': '2020-07-24T19:00:00Z',
#   'totalTestsViral': 162384,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 16208,
#   'deathConfirmed': 123,
#   'deathProbable': 21,
#   'fips': '16',
#   'positiveIncrease': 528,
#   'negativeIncrease': 2719,
#   'total': 163440,
#   'totalTestResults': 163440,
#   'totalTestResultsIncrease': 3247,
#   'posNeg': 163440,
#   'deathIncrease': 6,
#   'hospitalizedIncrease': 12,
#   'hash': '0bfe60ed5f6e1d74ff8324bb1a0c8b31c071d4ce',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'IL',
#   'positive': 171125,
#   'negative': 2300840,
#   'pending': None,
#   'hospitalizedCurrently': 1438,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 341,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 110,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 7589,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 2470723,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 169883,
#   'deathConfirmed': 7397,
#   'deathProbable': 192,
#   'fips': '17',
#   'positiveIncrease': 1426,
#   'negativeIncrease': 36774,
#   'total': 2471965,
#   'totalTestResults': 2471965,
#   'totalTestResultsIncrease': 38200,
#   'posNeg': 2471965,
#   'deathIncrease': 12,
#   'hospitalizedIncrease': 0,
#   'hash': '63b2471686beca7481b640f52ed52be7c986048b',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'IN',
#   'positive': 61520,
#   'negative': 628754,
#   'pending': None,
#   'hospitalizedCurrently': 824,
#   'hospitalizedCumulative': 8180,
#   'inIcuCurrently': 281,
#   'inIcuCumulative': 1736,
#   'onVentilatorCurrently': 63,
#   'onVentilatorCumulative': None,
#   'recovered': 43535,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 23:59',
#   'dateModified': '2020-07-24T23:59:00Z',
#   'checkTimeEt': '07/24 19:59',
#   'death': 2895,
#   'hospitalized': 8180,
#   'dateChecked': '2020-07-24T23:59:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': 2698,
#   'deathProbable': 197,
#   'fips': '18',
#   'positiveIncrease': 922,
#   'negativeIncrease': 10603,
#   'total': 690274,
#   'totalTestResults': 690274,
#   'totalTestResultsIncrease': 11525,
#   'posNeg': 690274,
#   'deathIncrease': 11,
#   'hospitalizedIncrease': 52,
#   'hash': 'a2fdccb25bc324cfa574837f16b7b67e366fb42f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'KS',
#   'positive': 25109,
#   'negative': 252858,
#   'pending': None,
#   'hospitalizedCurrently': 315,
#   'hospitalizedCumulative': 1596,
#   'inIcuCurrently': 98,
#   'inIcuCumulative': 459,
#   'onVentilatorCurrently': 24,
#   'onVentilatorCumulative': 166,
#   'recovered': 1077,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 10:00',
#   'dateModified': '2020-07-24T10:00:00Z',
#   'checkTimeEt': '07/24 06:00',
#   'death': 326,
#   'hospitalized': 1596,
#   'dateChecked': '2020-07-24T10:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '20',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 277967,
#   'totalTestResults': 277967,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 277967,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'eaa326fb21deed81461e6001cc79babb82ece817',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'KY',
#   'positive': 26764,
#   'negative': 514819,
#   'pending': None,
#   'hospitalizedCurrently': 595,
#   'hospitalizedCumulative': 3266,
#   'inIcuCurrently': 132,
#   'inIcuCumulative': 1126,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 7421,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 696,
#   'hospitalized': 3266,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 25390,
#   'deathConfirmed': 692,
#   'deathProbable': 4,
#   'fips': '21',
#   'positiveIncrease': 833,
#   'negativeIncrease': 7274,
#   'total': 541583,
#   'totalTestResults': 541583,
#   'totalTestResultsIncrease': 8107,
#   'posNeg': 541583,
#   'deathIncrease': 5,
#   'hospitalizedIncrease': 18,
#   'hash': 'c7085de7fcd27a2775c2b55021861937a39e9eb8',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'LA',
#   'positive': 103734,
#   'negative': 1095992,
#   'pending': None,
#   'hospitalizedCurrently': 1600,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 197,
#   'onVentilatorCumulative': None,
#   'recovered': 61456,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/24/2020 13:00',
#   'dateModified': '2020-07-24T13:00:00Z',
#   'checkTimeEt': '07/24 09:00',
#   'death': 3715,
#   'hospitalized': None,
#   'dateChecked': '2020-07-24T13:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': 3603,
#   'deathProbable': 112,
#   'fips': '22',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 1199726,
#   'totalTestResults': 1199726,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 1199726,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '8a2d7261c3f8915d7183761abcd81a7d063a26c8',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MA',
#   'positive': 115268,
#   'negative': 995615,
#   'pending': None,
#   'hospitalizedCurrently': 371,
#   'hospitalizedCumulative': 11813,
#   'inIcuCurrently': 50,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 27,
#   'onVentilatorCumulative': None,
#   'recovered': 96452,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 10:00',
#   'dateModified': '2020-07-25T10:00:00Z',
#   'checkTimeEt': '07/25 06:00',
#   'death': 8510,
#   'hospitalized': 11813,
#   'dateChecked': '2020-07-25T10:00:00Z',
#   'totalTestsViral': 1425973,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 108107,
#   'deathConfirmed': 8291,
#   'deathProbable': 219,
#   'fips': '25',
#   'positiveIncrease': 621,
#   'negativeIncrease': 24010,
#   'total': 1110883,
#   'totalTestResults': 1110883,
#   'totalTestResultsIncrease': 24631,
#   'posNeg': 1110883,
#   'deathIncrease': 26,
#   'hospitalizedIncrease': 43,
#   'hash': '69bf843d7a906260492bcbf03563bc4369ed24c6',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MD',
#   'positive': 83054,
#   'negative': 742272,
#   'pending': None,
#   'hospitalizedCurrently': 545,
#   'hospitalizedCumulative': 12188,
#   'inIcuCurrently': 157,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 5434,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/25/2020 10:00',
#   'dateModified': '2020-07-25T10:00:00Z',
#   'checkTimeEt': '07/25 06:00',
#   'death': 3433,
#   'hospitalized': 12188,
#   'dateChecked': '2020-07-25T10:00:00Z',
#   'totalTestsViral': 1075316,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 83054,
#   'deathConfirmed': 3304,
#   'deathProbable': 129,
#   'fips': '24',
#   'positiveIncrease': 1288,
#   'negativeIncrease': 19688,
#   'total': 825326,
#   'totalTestResults': 825326,
#   'totalTestResultsIncrease': 20976,
#   'posNeg': 825326,
#   'deathIncrease': 11,
#   'hospitalizedIncrease': 69,
#   'hash': 'eabcbf2c69e3bea7d51f725dbc645986dbe8e505',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'ME',
#   'positive': 3790,
#   'negative': 149583,
#   'pending': None,
#   'hospitalizedCurrently': 11,
#   'hospitalizedCumulative': 379,
#   'inIcuCurrently': 8,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 2,
#   'onVentilatorCumulative': None,
#   'recovered': 3281,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 23:59',
#   'dateModified': '2020-07-24T23:59:00Z',
#   'checkTimeEt': '07/24 19:59',
#   'death': 119,
#   'hospitalized': 379,
#   'dateChecked': '2020-07-24T23:59:00Z',
#   'totalTestsViral': 152970,
#   'positiveTestsViral': 4715,
#   'negativeTestsViral': 148061,
#   'positiveCasesViral': 3387,
#   'deathConfirmed': 118,
#   'deathProbable': 1,
#   'fips': '23',
#   'positiveIncrease': 33,
#   'negativeIncrease': 2720,
#   'total': 153373,
#   'totalTestResults': 153373,
#   'totalTestResultsIncrease': 2753,
#   'posNeg': 153373,
#   'deathIncrease': 1,
#   'hospitalizedIncrease': 1,
#   'hash': '401829cdc4250b95eaf5cb4772df47f7403e9c19',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MI',
#   'positive': 85072,
#   'negative': 1529574,
#   'pending': None,
#   'hospitalizedCurrently': 751,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 215,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 113,
#   'onVentilatorCumulative': None,
#   'recovered': 55162,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 00:00',
#   'dateModified': '2020-07-24T00:00:00Z',
#   'checkTimeEt': '07/23 20:00',
#   'death': 6400,
#   'hospitalized': None,
#   'dateChecked': '2020-07-24T00:00:00Z',
#   'totalTestsViral': 1637017,
#   'positiveTestsViral': 107443,
#   'negativeTestsViral': 1529574,
#   'positiveCasesViral': 76541,
#   'deathConfirmed': 6151,
#   'deathProbable': 249,
#   'fips': '26',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 1614646,
#   'totalTestResults': 1614646,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 1614646,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': 'ce8c625339afdc3ff5058ce4d0a2c1e472b377f6',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MN',
#   'positive': 50291,
#   'negative': 890405,
#   'pending': None,
#   'hospitalizedCurrently': 287,
#   'hospitalizedCumulative': 4889,
#   'inIcuCurrently': 115,
#   'inIcuCumulative': 1440,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 43625,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/24/2020 17:00',
#   'dateModified': '2020-07-24T17:00:00Z',
#   'checkTimeEt': '07/24 13:00',
#   'death': 1611,
#   'hospitalized': 4889,
#   'dateChecked': '2020-07-24T17:00:00Z',
#   'totalTestsViral': 940696,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 50291,
#   'deathConfirmed': 1571,
#   'deathProbable': 40,
#   'fips': '27',
#   'positiveIncrease': 803,
#   'negativeIncrease': 17017,
#   'total': 940696,
#   'totalTestResults': 940696,
#   'totalTestResultsIncrease': 17820,
#   'posNeg': 940696,
#   'deathIncrease': 5,
#   'hospitalizedIncrease': 37,
#   'hash': '82a24a2ff82b6785ba460309dd3030351e905e15',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MO',
#   'positive': 40709,
#   'negative': 579012,
#   'pending': None,
#   'hospitalizedCurrently': 1057,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 159,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 15:00',
#   'dateModified': '2020-07-25T15:00:00Z',
#   'checkTimeEt': '07/25 11:00',
#   'death': 1182,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T15:00:00Z',
#   'totalTestsViral': 795966,
#   'positiveTestsViral': 45726,
#   'negativeTestsViral': 748933,
#   'positiveCasesViral': 40709,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '29',
#   'positiveIncrease': 1357,
#   'negativeIncrease': 5749,
#   'total': 619721,
#   'totalTestResults': 619721,
#   'totalTestResultsIncrease': 7106,
#   'posNeg': 619721,
#   'deathIncrease': 4,
#   'hospitalizedIncrease': 0,
#   'hash': 'ce04aa02abb461ac97d0258467171c14794deb73',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MP',
#   'positive': 39,
#   'negative': 11300,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 4,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 29,
#   'dataQualityGrade': 'D',
#   'lastUpdateEt': '7/25/2020 07:47',
#   'dateModified': '2020-07-25T07:47:00Z',
#   'checkTimeEt': '07/25 03:47',
#   'death': 2,
#   'hospitalized': 4,
#   'dateChecked': '2020-07-25T07:47:00Z',
#   'totalTestsViral': 12745,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 39,
#   'deathConfirmed': 2,
#   'deathProbable': None,
#   'fips': '69',
#   'positiveIncrease': 1,
#   'negativeIncrease': 0,
#   'total': 11339,
#   'totalTestResults': 11339,
#   'totalTestResultsIncrease': 1,
#   'posNeg': 11339,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '42f2fa5e5556a3082725d2d6ef9956fa17f1ea7c',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MS',
#   'positive': 51097,
#   'negative': 370789,
#   'pending': None,
#   'hospitalizedCurrently': 1172,
#   'hospitalizedCumulative': 3982,
#   'inIcuCurrently': 295,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 159,
#   'onVentilatorCumulative': None,
#   'recovered': 30315,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 19:00',
#   'dateModified': '2020-07-24T19:00:00Z',
#   'checkTimeEt': '07/24 15:00',
#   'death': 1480,
#   'hospitalized': 3982,
#   'dateChecked': '2020-07-24T19:00:00Z',
#   'totalTestsViral': 421233,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 50444,
#   'deathConfirmed': 1443,
#   'deathProbable': 37,
#   'fips': '28',
#   'positiveIncrease': 1434,
#   'negativeIncrease': 8972,
#   'total': 421886,
#   'totalTestResults': 421886,
#   'totalTestResultsIncrease': 10406,
#   'posNeg': 421886,
#   'deathIncrease': 17,
#   'hospitalizedIncrease': 59,
#   'hash': '3c8608167200455c015abfae75b54ec7aff610d9',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'MT',
#   'positive': 3260,
#   'negative': 147755,
#   'pending': None,
#   'hospitalizedCurrently': 59,
#   'hospitalizedCumulative': 195,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 1977,
#   'dataQualityGrade': 'C',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 46,
#   'hospitalized': 195,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 3260,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '30',
#   'positiveIncrease': 221,
#   'negativeIncrease': 1594,
#   'total': 151015,
#   'totalTestResults': 151015,
#   'totalTestResultsIncrease': 1815,
#   'posNeg': 151015,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 4,
#   'hash': 'bd4d9a259b721fb3d1f80f429e616ba1e5cab21a',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'NC',
#   'positive': 111092,
#   'negative': 1467950,
#   'pending': None,
#   'hospitalizedCurrently': 1168,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 362,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 78707,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 13:00',
#   'dateModified': '2020-07-25T13:00:00Z',
#   'checkTimeEt': '07/25 09:00',
#   'death': 1778,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T13:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 111092,
#   'deathConfirmed': 1778,
#   'deathProbable': None,
#   'fips': '37',
#   'positiveIncrease': 2097,
#   'negativeIncrease': 26648,
#   'total': 1579042,
#   'totalTestResults': 1579042,
#   'totalTestResultsIncrease': 28745,
#   'posNeg': 1579042,
#   'deathIncrease': 32,
#   'hospitalizedIncrease': 0,
#   'hash': '279cadae29f21486f2ecfb884dab8f113f019aad',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'ND',
#   'positive': 5736,
#   'negative': 138524,
#   'pending': None,
#   'hospitalizedCurrently': 39,
#   'hospitalizedCumulative': 328,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 4671,
#   'dataQualityGrade': 'C',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 91,
#   'hospitalized': 328,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 284082,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 5736,
#   'deathConfirmed': 87,
#   'deathProbable': 4,
#   'fips': '38',
#   'positiveIncrease': 122,
#   'negativeIncrease': 1430,
#   'total': 144260,
#   'totalTestResults': 144260,
#   'totalTestResultsIncrease': 1552,
#   'posNeg': 144260,
#   'deathIncrease': 3,
#   'hospitalizedIncrease': 3,
#   'hash': 'd0db032511ad8a1cd6b1f48e016477b1fc0de240',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'NE',
#   'positive': 24174,
#   'negative': 228431,
#   'pending': None,
#   'hospitalizedCurrently': 122,
#   'hospitalizedCumulative': 1548,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 17999,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/24/2020 20:05',
#   'dateModified': '2020-07-24T20:05:00Z',
#   'checkTimeEt': '07/24 16:05',
#   'death': 316,
#   'hospitalized': 1548,
#   'dateChecked': '2020-07-24T20:05:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 24174,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '31',
#   'positiveIncrease': 356,
#   'negativeIncrease': 3175,
#   'total': 252605,
#   'totalTestResults': 252605,
#   'totalTestResultsIncrease': 3531,
#   'posNeg': 252605,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 0,
#   'hash': '366fa5e22808563bd0e1e15367a5d9b969d49244',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'NH',
#   'positive': 6415,
#   'negative': 145875,
#   'pending': None,
#   'hospitalizedCurrently': 27,
#   'hospitalizedCumulative': 686,
#   'inIcuCurrently': None,
#   'inIcuCumulative': 200,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 5438,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 09:00',
#   'dateModified': '2020-07-25T09:00:00Z',
#   'checkTimeEt': '07/25 05:00',
#   'death': 409,
#   'hospitalized': 686,
#   'dateChecked': '2020-07-25T09:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 6415,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '33',
#   'positiveIncrease': 97,
#   'negativeIncrease': 2401,
#   'total': 152290,
#   'totalTestResults': 152290,
#   'totalTestResultsIncrease': 2498,
#   'posNeg': 152290,
#   'deathIncrease': 4,
#   'hospitalizedIncrease': 5,
#   'hash': '220c76866dd254291836f06777a7dddc69d876cf',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'NJ',
#   'positive': 178858,
#   'negative': 1709299,
#   'pending': None,
#   'hospitalizedCurrently': 831,
#   'hospitalizedCumulative': 21314,
#   'inIcuCurrently': 143,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 56,
#   'onVentilatorCumulative': None,
#   'recovered': 32061,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 13:00',
#   'dateModified': '2020-07-25T13:00:00Z',
#   'checkTimeEt': '07/25 09:00',
#   'death': 15776,
#   'hospitalized': 21314,
#   'dateChecked': '2020-07-25T13:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 178858,
#   'deathConfirmed': 13856,
#   'deathProbable': 1920,
#   'fips': '34',
#   'positiveIncrease': 513,
#   'negativeIncrease': 0,
#   'total': 1888157,
#   'totalTestResults': 1888157,
#   'totalTestResultsIncrease': 513,
#   'posNeg': 1888157,
#   'deathIncrease': 11,
#   'hospitalizedIncrease': 130,
#   'hash': 'f9902cd2ac535a0d31e5bf03d7f9a850dab2760a',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'NM',
#   'positive': 18475,
#   'negative': 486702,
#   'pending': None,
#   'hospitalizedCurrently': 161,
#   'hospitalizedCumulative': 2525,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 7156,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/24/2020 17:30',
#   'dateModified': '2020-07-24T17:30:00Z',
#   'checkTimeEt': '07/24 13:30',
#   'death': 601,
#   'hospitalized': 2525,
#   'dateChecked': '2020-07-24T17:30:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 18475,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '35',
#   'positiveIncrease': 312,
#   'negativeIncrease': 7880,
#   'total': 505177,
#   'totalTestResults': 505177,
#   'totalTestResultsIncrease': 8192,
#   'posNeg': 505177,
#   'deathIncrease': 5,
#   'hospitalizedIncrease': 25,
#   'hash': '95f92d6e87dd0c28dd44a98f4752ba5f31b27483',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'NV',
#   'positive': 41816,
#   'negative': 388705,
#   'pending': None,
#   'hospitalizedCurrently': 1147,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 314,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 180,
#   'onVentilatorCumulative': None,
#   'recovered': 994,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 12:15',
#   'dateModified': '2020-07-25T12:15:00Z',
#   'checkTimeEt': '07/25 08:15',
#   'death': 732,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T12:15:00Z',
#   'totalTestsViral': 552480,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 41816,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '32',
#   'positiveIncrease': 931,
#   'negativeIncrease': 7719,
#   'total': 430521,
#   'totalTestResults': 430521,
#   'totalTestResultsIncrease': 8650,
#   'posNeg': 430521,
#   'deathIncrease': 10,
#   'hospitalizedIncrease': 0,
#   'hash': '8bb517be19965ea8f3054e0eb786fa9ba461a598',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'NY',
#   'positive': 411200,
#   'negative': 5105111,
#   'pending': None,
#   'hospitalizedCurrently': 646,
#   'hospitalizedCumulative': 89995,
#   'inIcuCurrently': 149,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 94,
#   'onVentilatorCumulative': None,
#   'recovered': 72632,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/24/2020 23:59',
#   'dateModified': '2020-07-24T23:59:00Z',
#   'checkTimeEt': '07/24 19:59',
#   'death': 25103,
#   'hospitalized': 89995,
#   'dateChecked': '2020-07-24T23:59:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 411200,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '36',
#   'positiveIncrease': 750,
#   'negativeIncrease': 70716,
#   'total': 5516311,
#   'totalTestResults': 5516311,
#   'totalTestResultsIncrease': 71466,
#   'posNeg': 5516311,
#   'deathIncrease': 13,
#   'hospitalizedIncrease': 0,
#   'hash': '638030b1b45a96c826f5552c3639754488ae2c6f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'OH',
#   'positive': 83184,
#   'negative': 1210638,
#   'pending': None,
#   'hospitalizedCurrently': 1054,
#   'hospitalizedCumulative': 10145,
#   'inIcuCurrently': 356,
#   'inIcuCumulative': 2437,
#   'onVentilatorCurrently': 167,
#   'onVentilatorCumulative': None,
#   'recovered': 57731,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 14:00',
#   'dateModified': '2020-07-25T14:00:00Z',
#   'checkTimeEt': '07/25 10:00',
#   'death': 3297,
#   'hospitalized': 10145,
#   'dateChecked': '2020-07-25T14:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 78735,
#   'deathConfirmed': 3039,
#   'deathProbable': 258,
#   'fips': '39',
#   'positiveIncrease': 1438,
#   'negativeIncrease': 24756,
#   'total': 1293822,
#   'totalTestResults': 1293822,
#   'totalTestResultsIncrease': 26194,
#   'posNeg': 1293822,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 73,
#   'hash': '4a38130b53be10eb44e4ba40b43bcf3d0e50d1fc',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'OK',
#   'positive': 30081,
#   'negative': 535628,
#   'pending': None,
#   'hospitalizedCurrently': 625,
#   'hospitalizedCumulative': 2768,
#   'inIcuCurrently': 225,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 24053,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 496,
#   'hospitalized': 2768,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': 573185,
#   'positiveTestsViral': 36489,
#   'negativeTestsViral': 535628,
#   'positiveCasesViral': 30081,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '40',
#   'positiveIncrease': 965,
#   'negativeIncrease': 41702,
#   'total': 565709,
#   'totalTestResults': 565709,
#   'totalTestResultsIncrease': 42667,
#   'posNeg': 565709,
#   'deathIncrease': 12,
#   'hospitalizedIncrease': 81,
#   'hash': '42fbf09aa35635c92441d4a938a0f73c49c22f47',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'OR',
#   'positive': 16492,
#   'negative': 357518,
#   'pending': None,
#   'hospitalizedCurrently': 233,
#   'hospitalizedCumulative': 1474,
#   'inIcuCurrently': 58,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 30,
#   'onVentilatorCumulative': None,
#   'recovered': 3541,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 03:01',
#   'dateModified': '2020-07-25T03:01:00Z',
#   'checkTimeEt': '07/24 23:01',
#   'death': 286,
#   'hospitalized': 1474,
#   'dateChecked': '2020-07-25T03:01:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': 357518,
#   'positiveCasesViral': 15273,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '41',
#   'positiveIncrease': 388,
#   'negativeIncrease': 7055,
#   'total': 374010,
#   'totalTestResults': 374010,
#   'totalTestResultsIncrease': 7443,
#   'posNeg': 374010,
#   'deathIncrease': 4,
#   'hospitalizedIncrease': 0,
#   'hash': '610b9da53f838371cbd170b6d6d827fb5e0c5382',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'PA',
#   'positive': 106625,
#   'negative': 1016705,
#   'pending': None,
#   'hospitalizedCurrently': 709,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 102,
#   'onVentilatorCumulative': None,
#   'recovered': 79968,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/25/2020 00:00',
#   'dateModified': '2020-07-25T00:00:00Z',
#   'checkTimeEt': '07/24 20:00',
#   'death': 7114,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T00:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 103632,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '42',
#   'positiveIncrease': 1054,
#   'negativeIncrease': 17328,
#   'total': 1123330,
#   'totalTestResults': 1123330,
#   'totalTestResultsIncrease': 18382,
#   'posNeg': 1123330,
#   'deathIncrease': 13,
#   'hospitalizedIncrease': 0,
#   'hash': '5a180be84d274c22ab71ca2eeadee90eda1b9943',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'PR',
#   'positive': 14540,
#   'negative': 305972,
#   'pending': None,
#   'hospitalizedCurrently': 496,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 57,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 35,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/25/2020 06:30',
#   'dateModified': '2020-07-25T06:30:00Z',
#   'checkTimeEt': '07/25 02:30',
#   'death': 201,
#   'hospitalized': None,
#   'dateChecked': '2020-07-25T06:30:00Z',
#   'totalTestsViral': 310546,
#   'positiveTestsViral': 7002,
#   'negativeTestsViral': 303412,
#   'positiveCasesViral': 5042,
#   'deathConfirmed': 99,
#   'deathProbable': 102,
#   'fips': '72',
#   'positiveIncrease': 573,
#   'negativeIncrease': 0,
#   'total': 320512,
#   'totalTestResults': 320512,
#   'totalTestResultsIncrease': 573,
#   'posNeg': 320512,
#   'deathIncrease': 10,
#   'hospitalizedIncrease': 0,
#   'hash': '54384be2032875fb9c3adfa1f65edfaf66a4d1cc',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200725,
#   'state': 'RI',
#   'positive': 18224,
#   'negative': 171804,
#   'pending': None,
#   'hospitalizedCurrently': 66,
#   'hospitalizedCumulative': 2146,
#   'inIcuCurrently': 6,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 5,
#   'onVentilatorCumulative': None,
#   'recovered': 1769,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/24/2020 12:00',
#   'dateModified': '2020-07-24T12:00:00Z',
#   'checkTimeEt': '07/24 08:00',
#   'death': 1002,
#   'hospitalized': 2146,
#   'dateChecked': '2020-07-24T12:00:00Z',
#   'totalTestsViral': 329556,
# ...
#   'negativeTestsViral': None,
#   'positiveCasesViral': 5932,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '33',
#   'positiveIncrease': 18,
#   'negativeIncrease': 613,
#   'total': 128511,
#   'totalTestResults': 128511,
#   'totalTestResultsIncrease': 631,
#   'posNeg': 128511,
#   'deathIncrease': 2,
#   'hospitalizedIncrease': 3,
#   'hash': '2df9d102a6a5e5f30b9d63a800a7b9f974b35386',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'NJ',
#   'positive': 174039,
#   'negative': 1403809,
#   'pending': None,
#   'hospitalizedCurrently': 935,
#   'hospitalizedCumulative': 20426,
#   'inIcuCurrently': 175,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 142,
#   'onVentilatorCumulative': None,
#   'recovered': 30844,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/8/2020 13:00',
#   'dateModified': '2020-07-08T13:00:00Z',
#   'checkTimeEt': '07/08 09:00',
#   'death': 15423,
#   'hospitalized': 20426,
#   'dateChecked': '2020-07-08T13:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 174039,
#   'deathConfirmed': 13476,
#   'deathProbable': 1947,
#   'fips': '34',
#   'positiveIncrease': 161,
#   'negativeIncrease': 17554,
#   'total': 1577848,
#   'totalTestResults': 1577848,
#   'totalTestResultsIncrease': 17715,
#   'posNeg': 1577848,
#   'deathIncrease': 142,
#   'hospitalizedIncrease': 180,
#   'hash': 'efea49f45cfa3cf2f4e58d7ea6da29fe04f5c454',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'NM',
#   'positive': 13727,
#   'negative': 371515,
#   'pending': None,
#   'hospitalizedCurrently': 133,
#   'hospitalizedCumulative': 2056,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 5986,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/7/2020 17:46',
#   'dateModified': '2020-07-07T17:46:00Z',
#   'checkTimeEt': '07/07 13:46',
#   'death': 519,
#   'hospitalized': 2056,
#   'dateChecked': '2020-07-07T17:46:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 13727,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '35',
#   'positiveIncrease': 220,
#   'negativeIncrease': 4782,
#   'total': 385242,
#   'totalTestResults': 385242,
#   'totalTestResultsIncrease': 5002,
#   'posNeg': 385242,
#   'deathIncrease': 4,
#   'hospitalizedIncrease': 23,
#   'hash': '620556076e7355e73a90495025a0f12f3dfa294e',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'NV',
#   'positive': 24301,
#   'negative': 299352,
#   'pending': None,
#   'hospitalizedCurrently': 876,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 233,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 109,
#   'onVentilatorCumulative': None,
#   'recovered': 754,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/8/2020 12:00',
#   'dateModified': '2020-07-08T12:00:00Z',
#   'checkTimeEt': '07/08 08:00',
#   'death': 553,
#   'hospitalized': None,
#   'dateChecked': '2020-07-08T12:00:00Z',
#   'totalTestsViral': 396632,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 24301,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '32',
#   'positiveIncrease': 516,
#   'negativeIncrease': 6591,
#   'total': 323653,
#   'totalTestResults': 323653,
#   'totalTestResultsIncrease': 7107,
#   'posNeg': 323653,
#   'deathIncrease': 5,
#   'hospitalizedIncrease': 0,
#   'hash': '5bacde1856353d7d10fa9821097073fabd0cf186',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'NY',
#   'positive': 398929,
#   'negative': 4003523,
#   'pending': None,
#   'hospitalizedCurrently': 841,
#   'hospitalizedCumulative': 89995,
#   'inIcuCurrently': 166,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 97,
#   'onVentilatorCumulative': None,
#   'recovered': 71185,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/7/2020 23:59',
#   'dateModified': '2020-07-07T23:59:00Z',
#   'checkTimeEt': '07/07 19:59',
#   'death': 24944,
#   'hospitalized': 89995,
#   'dateChecked': '2020-07-07T23:59:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 398929,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '36',
#   'positiveIncrease': 692,
#   'negativeIncrease': 56893,
#   'total': 4402452,
#   'totalTestResults': 4402452,
#   'totalTestResultsIncrease': 57585,
#   'posNeg': 4402452,
#   'deathIncrease': 20,
#   'hospitalizedIncrease': 0,
#   'hash': '1de945ffcfda0e9f18e1c10231f961c691095284',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'OH',
#   'positive': 60181,
#   'negative': 855071,
#   'pending': None,
#   'hospitalizedCurrently': 890,
#   'hospitalizedCumulative': 8489,
#   'inIcuCurrently': 289,
#   'inIcuCumulative': 2127,
#   'onVentilatorCurrently': 155,
#   'onVentilatorCumulative': None,
#   'recovered': 42111,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/8/2020 14:00',
#   'dateModified': '2020-07-08T14:00:00Z',
#   'checkTimeEt': '07/08 10:00',
#   'death': 2991,
#   'hospitalized': 8489,
#   'dateChecked': '2020-07-08T14:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 56384,
#   'deathConfirmed': 2737,
#   'deathProbable': 254,
#   'fips': '39',
#   'positiveIncrease': 1277,
#   'negativeIncrease': 17490,
#   'total': 915252,
#   'totalTestResults': 915252,
#   'totalTestResultsIncrease': 18767,
#   'posNeg': 915252,
#   'deathIncrease': 21,
#   'hospitalizedIncrease': 106,
#   'hash': '3d6f75a371b91d94e07fcac1b82070bdcf5c491d',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'OK',
#   'positive': 17893,
#   'negative': 376930,
#   'pending': None,
#   'hospitalizedCurrently': 458,
#   'hospitalizedCumulative': 1804,
#   'inIcuCurrently': 209,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 13538,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/8/2020 00:00',
#   'dateModified': '2020-07-08T00:00:00Z',
#   'checkTimeEt': '07/07 20:00',
#   'death': 407,
#   'hospitalized': 1804,
#   'dateChecked': '2020-07-08T00:00:00Z',
#   'totalTestsViral': 397647,
#   'positiveTestsViral': 19871,
#   'negativeTestsViral': 376930,
#   'positiveCasesViral': 17893,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '40',
#   'positiveIncrease': 673,
#   'negativeIncrease': 5132,
#   'total': 394823,
#   'totalTestResults': 394823,
#   'totalTestResultsIncrease': 5805,
#   'posNeg': 394823,
#   'deathIncrease': 3,
#   'hospitalizedIncrease': 63,
#   'hash': '6fa9635bb47aa8f0f8c5c9287a72091b14be5112',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'OR',
#   'positive': 10817,
#   'negative': 265450,
#   'pending': None,
#   'hospitalizedCurrently': 188,
#   'hospitalizedCumulative': 1155,
#   'inIcuCurrently': 57,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 27,
#   'onVentilatorCumulative': None,
#   'recovered': 2877,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/8/2020 03:01',
#   'dateModified': '2020-07-08T03:01:00Z',
#   'checkTimeEt': '07/07 23:01',
#   'death': 224,
#   'hospitalized': 1155,
#   'dateChecked': '2020-07-08T03:01:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': 265450,
#   'positiveCasesViral': 10277,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '41',
#   'positiveIncrease': 212,
#   'negativeIncrease': 4149,
#   'total': 276267,
#   'totalTestResults': 276267,
#   'totalTestResultsIncrease': 4361,
#   'posNeg': 276267,
#   'deathIncrease': 4,
#   'hospitalizedIncrease': 14,
#   'hash': '572b439ecf53f89cf01eec84a88dbabaa8025258',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'PA',
#   'positive': 92148,
#   'negative': 774378,
#   'pending': None,
#   'hospitalizedCurrently': 649,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 104,
#   'onVentilatorCumulative': None,
#   'recovered': 70953,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/8/2020 00:00',
#   'dateModified': '2020-07-08T00:00:00Z',
#   'checkTimeEt': '07/07 20:00',
#   'death': 6812,
#   'hospitalized': None,
#   'dateChecked': '2020-07-08T00:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': 89515,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '42',
#   'positiveIncrease': 849,
#   'negativeIncrease': 15575,
#   'total': 866526,
#   'totalTestResults': 866526,
#   'totalTestResultsIncrease': 16424,
#   'posNeg': 866526,
#   'deathIncrease': 25,
#   'hospitalizedIncrease': 0,
#   'hash': '8e5d910121e77b72c051223c9262a6ef9c7711e2',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'PR',
#   'positive': 8745,
#   'negative': 192686,
#   'pending': None,
#   'hospitalizedCurrently': 127,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': 9,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 10,
#   'onVentilatorCumulative': None,
#   'recovered': None,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/8/2020 06:30',
#   'dateModified': '2020-07-08T06:30:00Z',
#   'checkTimeEt': '07/08 02:30',
#   'death': 159,
#   'hospitalized': None,
#   'dateChecked': '2020-07-08T06:30:00Z',
#   'totalTestsViral': 194324,
#   'positiveTestsViral': 2627,
#   'negativeTestsViral': 191601,
#   'positiveCasesViral': 2171,
#   'deathConfirmed': 64,
#   'deathProbable': 95,
#   'fips': '72',
#   'positiveIncrease': 31,
#   'negativeIncrease': 0,
#   'total': 201431,
#   'totalTestResults': 201431,
#   'totalTestResultsIncrease': 31,
#   'posNeg': 201431,
#   'deathIncrease': 2,
#   'hospitalizedIncrease': 0,
#   'hash': '677a0c9bc9d423dd16c7e4ee2c62007303190d1d',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'RI',
#   'positive': 17204,
#   'negative': 146066,
#   'pending': None,
#   'hospitalizedCurrently': 56,
#   'hospitalizedCumulative': 2043,
#   'inIcuCurrently': 5,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': 5,
#   'onVentilatorCumulative': None,
#   'recovered': 1683,
#   'dataQualityGrade': 'A+',
#   'lastUpdateEt': '7/8/2020 00:00',
#   'dateModified': '2020-07-08T00:00:00Z',
#   'checkTimeEt': '07/07 20:00',
#   'death': 971,
#   'hospitalized': 2043,
#   'dateChecked': '2020-07-08T00:00:00Z',
#   'totalTestsViral': 271710,
#   'positiveTestsViral': 24698,
#   'negativeTestsViral': 247012,
#   'positiveCasesViral': 17204,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '44',
#   'positiveIncrease': 0,
#   'negativeIncrease': 0,
#   'total': 163270,
#   'totalTestResults': 163270,
#   'totalTestResultsIncrease': 0,
#   'posNeg': 163270,
#   'deathIncrease': 2,
#   'hospitalizedIncrease': 7,
#   'hash': '230bd34f3d33bc6bab5f4b5dde8c086c2b01ab9f',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'SC',
#   'positive': 48909,
#   'negative': 404931,
#   'pending': None,
#   'hospitalizedCurrently': 1404,
#   'hospitalizedCumulative': 3090,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 19181,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/7/2020 23:59',
#   'dateModified': '2020-07-07T23:59:00Z',
#   'checkTimeEt': '07/07 19:59',
#   'death': 884,
#   'hospitalized': 3090,
#   'dateChecked': '2020-07-07T23:59:00Z',
#   'totalTestsViral': 453701,
#   'positiveTestsViral': 61473,
#   'negativeTestsViral': 392228,
#   'positiveCasesViral': 48770,
#   'deathConfirmed': 876,
#   'deathProbable': 8,
#   'fips': '45',
#   'positiveIncrease': 1557,
#   'negativeIncrease': 6992,
#   'total': 453840,
#   'totalTestResults': 453840,
#   'totalTestResultsIncrease': 8549,
#   'posNeg': 453840,
#   'deathIncrease': 38,
#   'hospitalizedIncrease': 0,
#   'hash': '307b4bc4cce1618975c4d2eb68cd02696c46e676',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'SD',
#   'positive': 7242,
#   'negative': 78984,
#   'pending': None,
#   'hospitalizedCurrently': 54,
#   'hospitalizedCumulative': 709,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 6280,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/7/2020 18:00',
#   'dateModified': '2020-07-07T18:00:00Z',
#   'checkTimeEt': '07/07 14:00',
#   'death': 98,
#   'hospitalized': 709,
#   'dateChecked': '2020-07-07T18:00:00Z',
#   'totalTestsViral': None,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '46',
#   'positiveIncrease': 79,
#   'negativeIncrease': 782,
#   'total': 86226,
#   'totalTestResults': 86226,
#   'totalTestResultsIncrease': 861,
#   'posNeg': 86226,
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 10,
#   'hash': 'dde48d432af703bc5bd508286401bafc4e3a7011',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'TN',
#   'positive': 55986,
#   'negative': 894973,
#   'pending': None,
#   'hospitalizedCurrently': 1160,
#   'hospitalizedCumulative': 3023,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 32736,
#   'dataQualityGrade': 'A',
#   'lastUpdateEt': '7/8/2020 15:00',
#   'dateModified': '2020-07-08T15:00:00Z',
#   'checkTimeEt': '07/08 11:00',
#   'death': 685,
#   'hospitalized': 3023,
#   'dateChecked': '2020-07-08T15:00:00Z',
#   'totalTestsViral': 950540,
#   'positiveTestsViral': 65002,
#   'negativeTestsViral': 885538,
#   'positiveCasesViral': 55567,
#   'deathConfirmed': 660,
#   'deathProbable': 25,
#   'fips': '47',
#   'positiveIncrease': 2472,
#   'negativeIncrease': 27288,
#   'total': 950959,
#   'totalTestResults': 950959,
#   'totalTestResultsIncrease': 29760,
#   'posNeg': 950959,
#   'deathIncrease': 20,
#   'hospitalizedIncrease': 73,
#   'hash': '2b9cfd8418ae446862a1c0fa6df7247e01d2b34b',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  {'date': 20200708,
#   'state': 'TX',
#   'positive': 220564,
#   'negative': 2038144,
#   'pending': None,
#   'hospitalizedCurrently': 9610,
#   'hospitalizedCumulative': None,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 113284,
#   'dataQualityGrade': 'B',
#   'lastUpdateEt': '7/8/2020 17:45',
#   'dateModified': '2020-07-08T17:45:00Z',
#   'checkTimeEt': '07/08 13:45',
#   'death': 2813,
#   'hospitalized': None,
#   'dateChecked': '2020-07-08T17:45:00Z',
#   'totalTestsViral': 2258708,
#   'positiveTestsViral': None,
#   'negativeTestsViral': None,
#   'positiveCasesViral': None,
#   'deathConfirmed': None,
#   'deathProbable': None,
#   'fips': '48',
#   'positiveIncrease': 9979,
#   'negativeIncrease': 27442,
#   'total': 2258708,
#   'totalTestResults': 2258708,
#   'totalTestResultsIncrease': 37421,
#   'posNeg': 2258708,
#   'deathIncrease': 98,
#   'hospitalizedIncrease': 0,
#   'hash': 'bdb6fc0d4b140408466274f13b2519aa2c299f27',
#   'commercialScore': 0,
#   'negativeRegularScore': 0,
#   'negativeScore': 0,
#   'positiveScore': 0,
#   'score': 0,
#   'grade': ''},
#  ...]
