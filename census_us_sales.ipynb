# %%
import pandas as pd
import numpy as np
import datetime

# %%
us_data = "Resource/final_us_data.csv"

# %%
us_data_df = pd.read_csv(us_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
us_data_df.head()
# Out:
#    per_idx  per_name  cat_idx cat_code                      cat_desc  dt_idx  \
# 0        1  1/1/1992        5    44000           44000: Retail Trade       1
# 1        1  1/1/1992        5    44000           44000: Retail Trade       1
# 2        1  1/1/1992        6    4400A  4400A: Retail Trade, ex Auto       1
# 3        1  1/1/1992        6    4400A  4400A: Retail Trade, ex Auto       1
# 4        1  1/1/1992        7    4400C                   4400C: GAFO       1
#
#   dt_code          dt_desc dt_unit  geo_idx geo_code    geo_desc  adj_idx  \
# 0      SM  Sales - Monthly    MLN$        1       US  U.S. Total        0
# 1      SM  Sales - Monthly    MLN$        1       US  U.S. Total        1
# 2      SM  Sales - Monthly    MLN$        1       US  U.S. Total        0
# 3      SM  Sales - Monthly    MLN$        1       US  U.S. Total        1
# 4      SM  Sales - Monthly    MLN$        1       US  U.S. Total        0
#
#        adj_desc     val
# 0      adjusted  130683
# ...

# %%
reduced_us_df = us_data_df[["per_name", "cat_code", "cat_desc", "dt_desc","dt_unit", "geo_code", "val", "adj_desc"]]
reduced_us_df.head()
# Out:
#    per_name cat_code                      cat_desc          dt_desc dt_unit  \
# 0  1/1/1992    44000           44000: Retail Trade  Sales - Monthly    MLN$
# 1  1/1/1992    44000           44000: Retail Trade  Sales - Monthly    MLN$
# 2  1/1/1992    4400A  4400A: Retail Trade, ex Auto  Sales - Monthly    MLN$
# 3  1/1/1992    4400A  4400A: Retail Trade, ex Auto  Sales - Monthly    MLN$
# 4  1/1/1992    4400C                   4400C: GAFO  Sales - Monthly    MLN$
#
#   geo_code     val      adj_desc
# 0       US  130683      adjusted
# 1       US  146925  not adjusted
# 2       US  100872      adjusted
# 3       US  113447  not adjusted
# 4       US   33906      adjusted

# %%
renamed_us_df = reduced_us_df.rename(columns={"per_name": "Month/Year",
                                            "cat_code": "Category Code",
                                            "cat_desc": "Category Description",
                                            "dt_desc": "Data Type",
                                            "dt_unit": "Units",
                                            "geo_code": "Country",
                                            "val": "Total Sales",
                                             "adj_desc": "Adjusted Description"})
renamed_us_df.head()
# Out:
#   Month/Year Category Code          Category Description        Data Type  \
# 0   1/1/1992         44000           44000: Retail Trade  Sales - Monthly
# 1   1/1/1992         44000           44000: Retail Trade  Sales - Monthly
# 2   1/1/1992         4400A  4400A: Retail Trade, ex Auto  Sales - Monthly
# 3   1/1/1992         4400A  4400A: Retail Trade, ex Auto  Sales - Monthly
# 4   1/1/1992         4400C                   4400C: GAFO  Sales - Monthly
#
#   Units Country Total Sales Adjusted Description
# 0  MLN$      US      130683             adjusted
# 1  MLN$      US      146925         not adjusted
# 2  MLN$      US      100872             adjusted
# 3  MLN$      US      113447         not adjusted
# 4  MLN$      US       33906             adjusted

# %%
electronic_shopping_df = renamed_us_df.loc[renamed_us_df["Category Code"] == "4541"]
electronic_shopping_df.head()
# Out:
#     Month/Year Category Code                             Category Description  \
# 88    1/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 89    1/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 222   2/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 223   2/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 319   2/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
#
#                           Data Type Units Country Total Sales  \
# 88                  Sales - Monthly  MLN$      US        2692
# 89                  Sales - Monthly  MLN$      US        2668
# 222                 Sales - Monthly  MLN$      US        2285
# 223                 Sales - Monthly  MLN$      US        2632
# 319  Sales - Monthly Percent Change   PCT      US        -1.3
#
#     Adjusted Description
# 88              adjusted
# 89          not adjusted
# 222             adjusted
# ...

# %%
mon_sales_df = electronic_shopping_df.loc[electronic_shopping_df["Data Type"] == "Sales - Monthly"]
mon_sales_df.tail()
# Out:
#        Month/Year Category Code  \
# 154095   3/1/2020          4541
# 154692   4/1/2020          4541
# 154693   4/1/2020          4541
# 155133   5/1/2020          4541
# 155134   5/1/2020          4541
#
#                                    Category Description        Data Type  \
# 154095  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly
# 154692  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly
# 154693  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly
# 155133  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly
# 155134  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly
#
#        Units Country Total Sales Adjusted Description
# 154095  MLN$      US       65332         not adjusted
# 154692  MLN$      US       69952             adjusted
# 154693  MLN$      US       73479         not adjusted
# 155133  MLN$      US       75973             adjusted
# 155134  MLN$      US       78974         not adjusted

# %%
adj_desc_df = mon_sales_df.loc[mon_sales_df["Adjusted Description"] == "not adjusted"]
adj_desc_df.head()
# Out:
#     Month/Year Category Code                             Category Description  \
# 89    1/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 223   2/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 547   3/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 839   4/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 973   5/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
#
#            Data Type Units Country Total Sales Adjusted Description
# 89   Sales - Monthly  MLN$      US        2668         not adjusted
# 223  Sales - Monthly  MLN$      US        2632         not adjusted
# 547  Sales - Monthly  MLN$      US        2477         not adjusted
# 839  Sales - Monthly  MLN$      US        2757         not adjusted
# 973  Sales - Monthly  MLN$      US        2874         not adjusted

# %%
adj_desc_df[["Month", "Date", "Year"]]= adj_desc_df["Month/Year"].str.split("/", expand=True)
adj_desc_df.head(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#     Month/Year Category Code                             Category Description  \
# 89    1/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 223   2/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 547   3/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 839   4/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
# 973   5/1/1992          4541  4541: Electronic Shopping and Mail-order Houses
#
#            Data Type Units Country Total Sales Adjusted Description Month  \
# ...

# %%
tenyr_us_df = adj_desc_df.loc[adj_desc_df["Year"] >= "2010"]
tenyr_us_df.head(20)
# Out:
#       Month/Year Category Code  \
# 86330   1/1/2010          4541
# 86469   2/1/2010          4541
# 87107   3/1/2010          4541
# 88004   4/1/2010          4541
# 88143   5/1/2010          4541
# 88781   6/1/2010          4541
# 89678   7/1/2010          4541
# 89817   8/1/2010          4541
# 90455   9/1/2010          4541
# 91352  10/1/2010          4541
# 91491  11/1/2010          4541
# 92129  12/1/2010          4541
# 93026   1/1/2011          4541
# 93165   2/1/2011          4541
# 93803   3/1/2011          4541
# 94700   4/1/2011          4541
# 94839   5/1/2011          4541
# 95477   6/1/2011          4541
# 96374   7/1/2011          4541
# 96513   8/1/2011          4541
#
#                                   Category Description        Data Type Units  \
# 86330  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly  MLN$
# 86469  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly  MLN$
# ...

# %%
tenyr_us_df["Month"].replace({"1":"January",
                              "2":"February",
                              "3":"March",
                              "4":"April",
                              "5":"May",
                              "6":"June",
                              "7":"July",
                              "8":"August",
                              "9":"September",
                              "10":"October",
                              "11":"November",
                              "12":"December"}, inplace=True)
tenyr_us_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#       Month/Year Category Code  \
# 86330   1/1/2010          4541
# 86469   2/1/2010          4541
# 87107   3/1/2010          4541
# 88004   4/1/2010          4541
# 88143   5/1/2010          4541
#
#                                   Category Description        Data Type Units  \
# 86330  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly  MLN$
# 86469  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly  MLN$
# 87107  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly  MLN$
# 88004  4541: Electronic Shopping and Mail-order Houses  Sales - Monthly  MLN$
# ...

# %%
clean_us_df = tenyr_us_df[["Month","Year","Category Code","Category Description","Country","Total Sales","Units"]]
clean_us_df.head(95)
# Out:
#             Month  Year Category Code  \
# 86330     January  2010          4541
# 86469    February  2010          4541
# 87107       March  2010          4541
# 88004       April  2010          4541
# 88143         May  2010          4541
# ...           ...   ...           ...
# 136247       July  2017          4541
# 136684     August  2017          4541
# 137320  September  2017          4541
# 137918    October  2017          4541
# 138355   November  2017          4541
#
#                                    Category Description Country Total Sales  \
# 86330   4541: Electronic Shopping and Mail-order Houses      US       20726
# 86469   4541: Electronic Shopping and Mail-order Houses      US       20742
# 87107   4541: Electronic Shopping and Mail-order Houses      US       21521
# 88004   4541: Electronic Shopping and Mail-order Houses      US       21458
# 88143   4541: Electronic Shopping and Mail-order Houses      US       21459
# ...
