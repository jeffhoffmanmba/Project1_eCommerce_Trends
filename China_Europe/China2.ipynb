# %%
# %matplotlib notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Import Dependencies Libraries
import os
from matplotlib import pyplot
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sb
from pylab import rcParams
import random

# %%
# %matplotlib inline

# %%
# Load data using read_csv
from pandas import read_csv
China_ts_df = read_csv('china_cleaned_up_data_transpose.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
print(type(China_ts_df))
print(China_ts_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             Online Retail Sales Accumulated($US)  \
# Date
# 2020-06-20                           7339.702264
# 2020-05-20                           5725.694313
# 2020-04-20                           4374.956168
# 2020-03-20                           3159.408701
# 2020-02-20                           1954.179392
# ...                                          ...
# 2020-05-10                                   NaN
# 2020-04-10                                   NaN
# 2020-03-10                                   NaN
# 2020-02-10                                   NaN
# 2020-01-10                                   NaN
#
#             Online Retail Sales Accumulated Growth Rate(%)  \
# Date
# 2020-06-20                                        1.040367
# 2020-05-20                                        0.641322
# 2020-04-20                                        0.242277
# 2020-03-20                                       -0.114013
# ...

# %%
China_ts_df.dropna(how='all', inplace=True)
China_ts_df
# Out:
#             Online Retail Sales Accumulated($US)  \
# Date
# 2020-06-20                           7339.702264
# 2020-05-20                           5725.694313
# 2020-04-20                           4374.956168
# 2020-03-20                           3159.408701
# 2020-02-20                           1954.179392
# ...                                          ...
# 2020-05-10                                   NaN
# 2020-04-10                                   NaN
# 2020-03-10                                   NaN
# 2020-02-10                                   NaN
# 2020-01-10                                   NaN
#
#             Online Retail Sales Accumulated Growth Rate(%)  \
# Date
# 2020-06-20                                        1.040367
# 2020-05-20                                        0.641322
# 2020-04-20                                        0.242277
# 2020-03-20                                       -0.114013
# 2020-02-20                                       -0.427548
# ...

# %%
print(China_ts_df.describe())
# Out:
#        Online Retail Sales Accumulated($US)  \
# count                             27.000000
# mean                            7004.752188
# std                             3815.658931
# min                             1748.856591
# 25%                             4006.894347
# 50%                             6821.200553
# 75%                             9614.991584
# max                            15152.899690
#
#        Online Retail Sales Accumulated Growth Rate(%)  \
# count                                       27.000000
# mean                                         2.722583
# std                                          1.529119
# min                                         -0.427548
# 25%                                          2.258879
# 50%                                          2.536785
# 75%                                          3.933442
# max                                          5.315847
#
#        Online Retail Sales in Goods Accumulated($US)  \
# ...

# %%
pyplot.plot(China_ts_df)
pyplot.show()

# %%
China_ts_df2 = China_ts_df.sample(n=100, random_state=120, axis=0)
plt.xlabel=('Date')
plt.ylabel=('Online Retail Sales Accumulated($US)')

plt.title=('China Ecommerce Trends')
China_ts_df2['Online Retail Sales Accumulated($US)'].plot()

# %%
China_ts_df2 = go.Scatter(x=energy_series.index,
                         y=energy_series.values)
